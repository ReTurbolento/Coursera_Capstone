# %% [markdown]
# ### Coursera - IBM Data Science - Capstone project 1st Notebook

# %% [markdown]
# This notebook has been created within the frist module of the final course of the IBM Data Science certificates. It will be used for further analysis in the following modules.

# %%
import pandas as pd
import numpy as np
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
